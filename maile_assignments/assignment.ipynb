# %% [markdown]
# <h1>Pandas Groupby with Hurricane Data<h1>

# %% [markdown]
# Import Numpy, Pandas and Matplotlib and set the display options. Use the following code to load a CSV file of the NOAA IBTrACS hurricane dataset:

# %%
import pandas as pd
import numpy as np 
from matplotlib import pyplot as plt 
#display options
plt.rcParams['figure.figsize'] = (12,7)
# %matplotlib inline

url = 'https://www.ncei.noaa.gov/data/international-best-track-archive-for-climate-stewardship-ibtracs/v04r00/access/csv/ibtracs.ALL.list.v04r00.csv'
df = pd.read_csv(url, parse_dates=['ISO_TIME'], usecols=range(12),
                 skiprows=[1], na_values=[' ', 'NOT_NAMED'],
                 keep_default_na=False, dtype={'NAME': str})
df.head()
# Out:
#              SID  SEASON  NUMBER BASIN SUBBASIN NAME            ISO_TIME  \
# 0  1842298N11080    1842       1    NI       BB  NaN 1842-10-25 03:00:00
# 1  1842298N11080    1842       1    NI       BB  NaN 1842-10-25 06:00:00
# 2  1842298N11080    1842       1    NI       BB  NaN 1842-10-25 09:00:00
# 3  1842298N11080    1842       1    NI       BB  NaN 1842-10-25 12:00:00
# 4  1842298N11080    1842       1    NI       BB  NaN 1842-10-25 15:00:00
#
#   NATURE      LAT      LON  WMO_WIND  WMO_PRES
# 0     NR  10.9000  80.3000       NaN       NaN
# 1     NR  10.8709  79.8265       NaN       NaN
# 2     NR  10.8431  79.3524       NaN       NaN
# 3     NR  10.8188  78.8772       NaN       NaN
# 4     NR  10.8000  78.4000       NaN       NaN

# %% [markdown]
# Basin Key: (NI - North Indian, SI - South Indian, WP - Western Pacific, SP - Southern Pacific, EP - Eastern Pacific, NA - North Atlantic)

# %% [markdown]
# How many rows does this dataset have? (715666 rows)

# %%
len(df)
# Out:
# 715695

# %% [markdown]
# How many North Atlantic hurricanes are in this dataset? (126593)

# %%
len(df[df["BASIN"] == "NA"])
# Out:
# 126593

# %% [markdown]
# 1) Get the unique values of the BASIN, SUBBASIN, and NATURE columns

# %%
unique_basin = df["BASIN"].unique()
unique_subbasin = df["SUBBASIN"].unique()
unique_nature = df["NATURE"].unique()

# %%
unique_basin
unique_subbasin
unique_nature
# Out:
# array(['NR', 'TS', 'ET', 'SS', 'MX', 'DS'], dtype=object)

# %% [markdown]
# 2) Rename the WMO_WIND and WMO_PRES columns to WIND and PRES

# %%
df.rename(columns={"WMO_WIND":"WIND"}, inplace = True) #have to access dictionary bc the column name is basically the key to all the values in the dataset
df.rename(columns={"WMO_PRES":"PRES"}, inplace = True)
df.head()
# Out:
#              SID  SEASON  NUMBER BASIN SUBBASIN NAME            ISO_TIME  \
# 0  1842298N11080    1842       1    NI       BB  NaN 1842-10-25 03:00:00
# 1  1842298N11080    1842       1    NI       BB  NaN 1842-10-25 06:00:00
# 2  1842298N11080    1842       1    NI       BB  NaN 1842-10-25 09:00:00
# 3  1842298N11080    1842       1    NI       BB  NaN 1842-10-25 12:00:00
# 4  1842298N11080    1842       1    NI       BB  NaN 1842-10-25 15:00:00
#
#   NATURE      LAT      LON  WIND  PRES
# 0     NR  10.9000  80.3000   NaN   NaN
# 1     NR  10.8709  79.8265   NaN   NaN
# 2     NR  10.8431  79.3524   NaN   NaN
# 3     NR  10.8188  78.8772   NaN   NaN
# 4     NR  10.8000  78.4000   NaN   NaN

# %% [markdown]
# 3) Get the 10 largest rows in the dataset by WIND

# %%
df.nlargest(10, "WIND")
# Out:
#                   SID  SEASON  NUMBER BASIN SUBBASIN      NAME  \
# 666142  2015293N13266    2015      96    EP       MM  PATRICIA
# 666140  2015293N13266    2015      96    EP       MM  PATRICIA
# 666144  2015293N13266    2015      96    EP       MM  PATRICIA
# 427655  1980214N11330    1980      57    NA       GM     ALLEN
# 178210  1935241N23291    1935      46    NA       NA       NaN
# 178211  1935241N23291    1935      46    NA       NA       NaN
# 178213  1935241N23291    1935      46    NA       GM       NaN
# 482093  1988253N12306    1988      74    NA       CS   GILBERT
# 552477  1997253N12255    1997      81    EP       MM     LINDA
# 605764  2005289N18282    2005      97    NA       CS     WILMA
#
#                   ISO_TIME NATURE   LAT    LON   WIND   PRES
# 666142 2015-10-23 12:00:00     TS  17.3 -105.6  185.0  872.0
# 666140 2015-10-23 06:00:00     TS  16.5 -105.4  180.0  886.0
# 666144 2015-10-23 18:00:00     TS  18.3 -105.3  180.0  878.0
# 427655 1980-08-07 18:00:00     TS  21.8  -86.4  165.0  899.0
# 178210 1935-09-03 00:00:00     TS  24.6  -80.5  160.0  892.0
# 178211 1935-09-03 02:00:00     TS  24.8  -80.8  160.0  892.0
# 178213 1935-09-03 06:00:00     TS  25.1  -81.1  160.0    NaN
# 482093 1988-09-14 00:00:00     TS  19.7  -83.8  160.0  888.0
# 552477 1997-09-12 06:00:00     TS  17.1 -109.6  160.0  902.0
# 605764 2005-10-19 12:00:00     TS  17.3  -82.8  160.0  882.0

# %% [markdown]
# 4) Group the data on SID and get the 10 largest hurricanes by WIND

# %%
sid_group = df.groupby("SID")
#can't do nlargest bc the dataframeobject has no attribute to nlargest but have to access the series first thru np
sid_group["WIND"].aggregate(np.max).nlargest(10)
# Out:
# SID
# 2015293N13266    185.0
# 1980214N11330    165.0
# 1935241N23291    160.0
# 1988253N12306    160.0
# 1997253N12255    160.0
# 2005289N18282    160.0
# 2019236N10314    160.0
# 1998295N12284    155.0
# 2005261N21290    155.0
# 2009288N07267    155.0
# Name: WIND, dtype: float64

# %% [markdown]
# 5) Make a bar chart of the wind speed of the 20 strongest-wind hurricanes. Use the name on the x-axis.

# %%
#strongest 20 wind hurricanes
name_group = df.groupby("NAME")
#have to groupby name in order to use name for x-axis and avoid repeats
name_group.aggregate(np.max).nlargest(20, "WIND").plot(kind="bar")
# Out:
# <Axes: xlabel='NAME'>

# %% [markdown]
# 6) Plot the count of all datapoints by Basin as a bar chart

# %%
#i decided to just aggregate to the dataframe itself
basin_group_count = df.groupby("BASIN").aggregate("count")
basin_group_count.plot(kind = "bar")
# Out:
# <Axes: xlabel='BASIN'>

# %% [markdown]
# 7) Plot the count of unique hurricanes by Basin as a bar chart.

# %%
df.groupby("BASIN")["NAME"].nunique()
# Out:
# BASIN
# EP    486
# NA    306
# NI    133
# SA      0
# SI    880
# SP    435
# WP    604
# Name: NAME, dtype: int64

# %%
#how do i get unique hurricanes by basin w/o it being an array 
basin_group_unique = df.groupby("BASIN")["NAME"].nunique()
basin_group_unique.plot(kind="bar")
plt.title("Count of Unique Hurricanes by Basin")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# 8) Make a hexbin of the location of datapoints in Latitude and Longitude

# %%
#what is a hexbin (hexagonal binning plot)

# Hexbin is a 2d histogram plot, so for each dot in 2D (lat, lon) space, the value is given in color.

df.plot.hexbin("LON", "LAT")
# Out:
# <Axes: xlabel='LON', ylabel='LAT'>

# %% [markdown]
# 9) Find Hurricane Katrina (from 2005) and plot its track as a scatter plot. First find the SID of this hurricane. Next get this hurricane’s group and plot its position as a scatter plot. Use wind speed to color the points.

# %%
#get sid
katrina_df = df[(df["NAME"] == "KATRINA") & (df["SEASON"] == 2005)]
#we could groupby and then access sid column
katrina_sid = "2005236N23285"
katrina_group = df[df["SID"] == katrina_sid]
katrina_group.plot.scatter("LON", "LAT", c = "WIND")
# Out:
# <Axes: xlabel='LON', ylabel='LAT'>

# %% [markdown]
# 10) Make time the index on your dataframe

# %%
df = df.set_index("ISO_TIME")

# %% [markdown]
# 11) Plot the count of all datapoints per year as a timeseries. You should use resample.

# %%
#get the year grouped and the count per year
# year_group_count = df.groupby(df.index.year).resample("M").aggregate("count")
#plot
year_group_count = df.resample("Y").count()
year_group_count.plot()
# Out:
# <Axes: xlabel='ISO_TIME'>

# %% [markdown]
# 12) Plot all tracks from the North Atlantic in 2005. You will probably have to iterate through a GroupBy object.

# %%
#did i have to use groupby ??
# I think this is good!
north_atlantic = df[(df["BASIN"] == "NA") & (df["SEASON"] == 2005)]
#plot?? does it want it by position?
#iterate thru groupby object
north_atlantic.plot()
# Out:
# <Axes: xlabel='ISO_TIME'>

# %%
north_atlantic
# Out:
#                                SID  SEASON  NUMBER BASIN SUBBASIN    NAME  \
# ISO_TIME
# 2005-06-08 18:00:00  2005160N17276    2005      31    NA       CS  ARLENE
# 2005-06-08 21:00:00  2005160N17276    2005      31    NA       CS  ARLENE
# 2005-06-09 00:00:00  2005160N17276    2005      31    NA       CS  ARLENE
# 2005-06-09 03:00:00  2005160N17276    2005      31    NA       CS  ARLENE
# 2005-06-09 06:00:00  2005160N17276    2005      31    NA       CS  ARLENE
# ...                            ...     ...     ...   ...      ...     ...
# 2006-01-07 06:00:00  2005364N24324    2005     115    NA       NA    ZETA
# 2006-01-07 09:00:00  2005364N24324    2005     115    NA       NA    ZETA
# 2006-01-07 12:00:00  2005364N24324    2005     115    NA       NA    ZETA
# 2006-01-07 15:00:00  2005364N24324    2005     115    NA       NA    ZETA
# 2006-01-07 18:00:00  2005364N24324    2005     115    NA       NA    ZETA
#
#                     NATURE      LAT      LON  WIND    PRES
# ISO_TIME
# 2005-06-08 18:00:00     TS  16.9000 -84.0000  25.0  1004.0
# 2005-06-08 21:00:00     TS  17.1200 -83.9425   NaN     NaN
# 2005-06-09 00:00:00     TS  17.4000 -83.9000  30.0  1003.0
# 2005-06-09 03:00:00     TS  17.7775 -83.8850   NaN     NaN
# 2005-06-09 06:00:00     TS  18.2000 -83.9000  35.0  1003.0
# ...                    ...      ...      ...   ...     ...
# 2006-01-07 06:00:00     DS  24.2000 -52.7000  25.0  1012.0
# 2006-01-07 09:00:00     DS  24.4249 -53.4364   NaN     NaN
# 2006-01-07 12:00:00     DS  24.8000 -54.2000  25.0  1014.0
# 2006-01-07 15:00:00     DS  25.4631 -54.9521   NaN     NaN
# 2006-01-07 18:00:00     DS  26.3000 -55.7000  25.0  1016.0
#
# [1807 rows x 11 columns]

# %% [markdown]
# 13) Create a filtered dataframe that contains only data since 1970 from the North Atlantic (“NA”) Basin

# %%
na_basin = df[(df["BASIN"] == "NA") & (df["SEASON"] >= 1970)]
na_basin.head()
# Out:
#                                SID  SEASON  NUMBER BASIN SUBBASIN  NAME  \
# ISO_TIME
# 1970-05-17 18:00:00  1970138N12281    1970      43    NA       CS  ALMA
# 1970-05-17 21:00:00  1970138N12281    1970      43    NA       CS  ALMA
# 1970-05-18 00:00:00  1970138N12281    1970      43    NA       CS  ALMA
# 1970-05-18 03:00:00  1970138N12281    1970      43    NA       CS  ALMA
# 1970-05-18 06:00:00  1970138N12281    1970      43    NA       CS  ALMA
#
#                     NATURE      LAT      LON  WIND  PRES
# ISO_TIME
# 1970-05-17 18:00:00     TS  11.5000 -79.0000  25.0   NaN
# 1970-05-17 21:00:00     TS  11.6475 -79.1400   NaN   NaN
# 1970-05-18 00:00:00     TS  11.8000 -79.3000  25.0   NaN
# 1970-05-18 03:00:00     TS  11.9575 -79.4925   NaN   NaN
# 1970-05-18 06:00:00     TS  12.1000 -79.7000  25.0   NaN

# %% [markdown]
# 14) Plot the number of datapoints per day from this filtered dataframe. Make sure you figure is big enough to actually see the plot

# %%
na_basin_day = na_basin.groupby(na_basin.index.day).aggregate("count")
na_basin_day.plot()
# Out:
# <Axes: xlabel='ISO_TIME'>

# %%
na_basin_day
# Out:
#            SID  SEASON  NUMBER  BASIN  SUBBASIN  NAME  NATURE   LAT   LON  \
# ISO_TIME
# 1         1618    1618    1618   1618      1618  1416    1618  1618  1618
# 2         1568    1568    1568   1568      1568  1375    1568  1568  1568
# 3         1558    1558    1558   1558      1558  1367    1558  1558  1558
# 4         1620    1620    1620   1620      1620  1379    1620  1620  1620
# 5         1594    1594    1594   1594      1594  1366    1594  1594  1594
# 6         1637    1637    1637   1637      1637  1388    1637  1637  1637
# 7         1626    1626    1626   1626      1626  1371    1626  1626  1626
# 8         1642    1642    1642   1642      1642  1390    1642  1642  1642
# 9         1576    1576    1576   1576      1576  1340    1576  1576  1576
# 10        1510    1510    1510   1510      1510  1277    1510  1510  1510
# 11        1500    1500    1500   1500      1500  1240    1500  1500  1500
# 12        1538    1538    1538   1538      1538  1273    1538  1538  1538
# 13        1563    1563    1563   1563      1563  1284    1563  1563  1563
# 14        1555    1555    1555   1555      1555  1295    1555  1555  1555
# 15        1566    1566    1566   1566      1566  1337    1566  1566  1566
# 16        1571    1571    1571   1571      1571  1338    1571  1571  1571
# 17        1557    1557    1557   1557      1557  1332    1557  1557  1557
# 18        1567    1567    1567   1567      1567  1371    1567  1567  1567
# 19        1592    1592    1592   1592      1592  1396    1592  1592  1592
# 20        1611    1611    1611   1611      1611  1389    1611  1611  1611
# 21        1569    1569    1569   1569      1569  1379    1569  1569  1569
# 22        1552    1552    1552   1552      1552  1374    1552  1552  1552
# 23        1570    1570    1570   1570      1570  1392    1570  1570  1570
# 24        1638    1638    1638   1638      1638  1407    1638  1638  1638
# 25        1667    1667    1667   1667      1667  1357    1667  1667  1667
# 26        1610    1610    1610   1610      1610  1329    1610  1610  1610
# 27        1560    1560    1560   1560      1560  1332    1560  1560  1560
# 28        1579    1579    1579   1579      1579  1357    1579  1579  1579
# 29        1543    1543    1543   1543      1543  1359    1543  1543  1543
# 30        1495    1495    1495   1495      1495  1325    1495  1495  1495
# 31        1003    1003    1003   1003      1003   876    1003  1003  1003
#
#           WIND  PRES
# ISO_TIME
# 1          795   692
# 2          786   662
# 3          788   654
# 4          822   666
# 5          807   666
# 6          836   700
# 7          825   694
# 8          830   719
# 9          795   690
# 10         758   645
# 11         748   617
# 12         764   629
# 13         778   616
# 14         771   638
# 15         779   674
# 16         770   673
# 17         770   666
# 18         772   652
# 19         782   654
# 20         788   654
# 21         763   642
# 22         748   653
# 23         755   649
# 24         801   680
# 25         820   684
# 26         797   660
# 27         769   649
# 28         789   678
# 29         769   680
# 30         734   655
# 31         489   413

# %% [markdown]
# 15) Calculate the climatology of datapoint counts as a function of dayofyear. Plot the mean and standard deviation on a single figure

# %%
na_basin.groupby(na_basin.index.dayofyear)

# %%
na_basin
# Out:
#                                SID  SEASON  NUMBER BASIN SUBBASIN  NAME  \
# ISO_TIME
# 1970-05-17 18:00:00  1970138N12281    1970      43    NA       CS  ALMA
# 1970-05-17 21:00:00  1970138N12281    1970      43    NA       CS  ALMA
# 1970-05-18 00:00:00  1970138N12281    1970      43    NA       CS  ALMA
# 1970-05-18 03:00:00  1970138N12281    1970      43    NA       CS  ALMA
# 1970-05-18 06:00:00  1970138N12281    1970      43    NA       CS  ALMA
# ...                            ...     ...     ...   ...      ...   ...
# 2023-11-17 12:00:00  2023319N11282    2023      81    NA       CS   NaN
# 2023-11-17 15:00:00  2023319N11282    2023      81    NA       CS   NaN
# 2023-11-17 18:00:00  2023319N11282    2023      81    NA       CS   NaN
# 2023-11-17 21:00:00  2023319N11282    2023      81    NA       CS   NaN
# 2023-11-18 00:00:00  2023319N11282    2023      81    NA       CS   NaN
#
#                     NATURE      LAT      LON  WIND  PRES
# ISO_TIME
# 1970-05-17 18:00:00     TS  11.5000 -79.0000  25.0   NaN
# 1970-05-17 21:00:00     TS  11.6475 -79.1400   NaN   NaN
# 1970-05-18 00:00:00     TS  11.8000 -79.3000  25.0   NaN
# 1970-05-18 03:00:00     TS  11.9575 -79.4925   NaN   NaN
# 1970-05-18 06:00:00     TS  12.1000 -79.7000  25.0   NaN
# ...                    ...      ...      ...   ...   ...
# 2023-11-17 12:00:00     NR  17.0364 -79.8000   NaN   NaN
# 2023-11-17 15:00:00     NR  17.4991 -79.1718   NaN   NaN
# 2023-11-17 18:00:00     NR  18.0000 -78.5000   NaN   NaN
# 2023-11-17 21:00:00     NR  18.6166 -77.8437   NaN   NaN
# 2023-11-18 00:00:00     NR  19.3000 -77.2000   NaN   NaN
#
# [48355 rows x 11 columns]

# %%
na_basin_day
# Out:
#            SID  SEASON  NUMBER  BASIN  SUBBASIN  NAME  NATURE   LAT   LON  \
# ISO_TIME
# 1         1618    1618    1618   1618      1618  1416    1618  1618  1618
# 2         1568    1568    1568   1568      1568  1375    1568  1568  1568
# 3         1558    1558    1558   1558      1558  1367    1558  1558  1558
# 4         1620    1620    1620   1620      1620  1379    1620  1620  1620
# 5         1594    1594    1594   1594      1594  1366    1594  1594  1594
# 6         1637    1637    1637   1637      1637  1388    1637  1637  1637
# 7         1626    1626    1626   1626      1626  1371    1626  1626  1626
# 8         1642    1642    1642   1642      1642  1390    1642  1642  1642
# 9         1576    1576    1576   1576      1576  1340    1576  1576  1576
# 10        1510    1510    1510   1510      1510  1277    1510  1510  1510
# 11        1500    1500    1500   1500      1500  1240    1500  1500  1500
# 12        1538    1538    1538   1538      1538  1273    1538  1538  1538
# 13        1563    1563    1563   1563      1563  1284    1563  1563  1563
# 14        1555    1555    1555   1555      1555  1295    1555  1555  1555
# 15        1566    1566    1566   1566      1566  1337    1566  1566  1566
# 16        1571    1571    1571   1571      1571  1338    1571  1571  1571
# 17        1557    1557    1557   1557      1557  1332    1557  1557  1557
# 18        1567    1567    1567   1567      1567  1371    1567  1567  1567
# 19        1592    1592    1592   1592      1592  1396    1592  1592  1592
# 20        1611    1611    1611   1611      1611  1389    1611  1611  1611
# 21        1569    1569    1569   1569      1569  1379    1569  1569  1569
# 22        1552    1552    1552   1552      1552  1374    1552  1552  1552
# 23        1570    1570    1570   1570      1570  1392    1570  1570  1570
# 24        1638    1638    1638   1638      1638  1407    1638  1638  1638
# 25        1667    1667    1667   1667      1667  1357    1667  1667  1667
# 26        1610    1610    1610   1610      1610  1329    1610  1610  1610
# 27        1560    1560    1560   1560      1560  1332    1560  1560  1560
# 28        1579    1579    1579   1579      1579  1357    1579  1579  1579
# 29        1543    1543    1543   1543      1543  1359    1543  1543  1543
# 30        1495    1495    1495   1495      1495  1325    1495  1495  1495
# 31        1003    1003    1003   1003      1003   876    1003  1003  1003
#
#           WIND  PRES
# ISO_TIME
# 1          795   692
# 2          786   662
# 3          788   654
# 4          822   666
# 5          807   666
# 6          836   700
# 7          825   694
# 8          830   719
# 9          795   690
# 10         758   645
# 11         748   617
# 12         764   629
# 13         778   616
# 14         771   638
# 15         779   674
# 16         770   673
# 17         770   666
# 18         772   652
# 19         782   654
# 20         788   654
# 21         763   642
# 22         748   653
# 23         755   649
# 24         801   680
# 25         820   684
# 26         797   660
# 27         769   649
# 28         789   678
# 29         769   680
# 30         734   655
# 31         489   413

# %%
#datapoint of na_basin
#what do we get the climatology of??????????
#problem is that the mean and std are the same values 
daily_climatology_mean = na_basin.groupby(na_basin.index.dayofyear).mean()
daily_climatology_std = na_basin.groupby(na_basin.index.dayofyear).std()
#fig, ax = plt.subplots(figsize = (10, 5))
plt.errorbar(daily_climatology_mean.index, daily_climatology_mean['PRES'], yerr=daily_climatology_std["PRES"])
#daily_climatology_mean.plot()
#daily_climatology_std.plot()
# Out:
# C:\Users\mailes2\AppData\Local\Temp\ipykernel_6136\1678629771.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   daily_climatology_mean = na_basin.groupby(na_basin.index.dayofyear).mean()
# C:\Users\mailes2\AppData\Local\Temp\ipykernel_6136\1678629771.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   daily_climatology_std = na_basin.groupby(na_basin.index.dayofyear).std()
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# 16) Use transform to calculate the anomaly of daily counts from the climatology

# %% [markdown]
# NOTE: I can't do 15 and 16.
